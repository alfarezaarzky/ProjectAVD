# %% [markdown]
# # **ANALISIS FAKTOR YANG MEMPENGARUHI PERFORMA AKADEMIK SISWA** #

# %% [markdown]
#  # **Import Library**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file = '/content/StudentPerformanceFactors.csv'
df = pd.read_csv(file)

# %% [markdown]
# # **Memuat Dataset**

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# # **Bussines Understanding**

# %% [markdown]
# ## **Bussiness Objective**

# %% [markdown]
# Tujuan bisnis utama adalah meningkatkan performa akademik siswa berdasarkan faktor-faktor yang memengaruhinya. Sekolah ingin mengetahui variabel apa saja yang memiliki dampak signifikan terhadap nilai siswa agar dapat merancang kebijakan yang lebih efektif. Secara spesifik, tujuan bisnis meliputi:
# 1. Meningkatkan rata-rata nilai siswa.
# 2. Mengurangi jumlah siswa dengan performa rendah.
# 3. Mengoptimalkan program pendukung seperti bimbingan belajar dan konseling.
# 4. Membantu pengambilan keputusan berbasis data.

# %% [markdown]
# ## **Assess Situation**

# %% [markdown]
# Sekolah memiliki data terkait berbagai faktor yang memengaruhi performa siswa, seperti jam belajar, kehadiran, dukungan orang tua, akses internet, dan motivasi belajar. Namun, data tersebut belum dimanfaatkan secara optimal untuk analisis mendalam.Tantangan yang dihadapi antara lain :
# 1. Belum diketahui faktor dominan yang paling berpengaruh.
# 2. Belum adanya sistem prediksi untuk mendeteksi siswa berisiko.
# 3. Pengambilan keputusan masih berbasis asumsi, bukan analisis data.

# %% [markdown]
# ## **Analytic Goals Project Plan**

# %% [markdown]
# Rencana proyek ini mencakup langkah-langkah terstruktur dari pengolahan data hingga penyajian hasil untuk mencapai tujuan bisnis yang telah ditetapkan :
#
# 1. Pengumpulan dan Eksplorasi Data (Data Understanding)
# 2. Pembersihan dan Persiapan Data (Data Preparation)
# 3. Analisis Data (Data Analysis)
# 4. Analisis Segmentasi Siswa
# 5. Visualisasi Data dan Reporting
#
# Tujuan utama dari analisis dataset ini adalah menghasilkan wawasan yang dapat digunakan untuk meningkatkan kualitas pendidikan dan performa akademik siswa.
#
# 1. Mengindentifikasi Faktor Utama yang Mempengaruhi Performa Siswa
# 2. Menganalisis Hubungan Kebiasaan Belajar dengan Prestasi
# 3. Evaluasi Peran Faktor Sosial dan Lingkungan
# 4. Memahami Segmentasi Siswa
# 5. Mengahsilkan Visualisasi Data yang Informatif
# 6. Menyediakan Dasar Pengambilan Keputusan

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Deskripsi Data**

# %% [markdown]
# ### **Informasi Lanjutan**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %% [markdown]
# 1. Hours_Studied: 0 Jumlah baris: 6607 Tipe data: int64 Deskripsi: Jumlah jam belajar siswa
# 2. Attendance: Jumlah baris: 6607 Tipe data: int64 Deskripsi: Tingkat kehadiran siswa
# 3. Parental_Involment: Jumlah baris: 6607 Tipe data: object Deskripsi: Keterlibatan orangtua siswa
# 4. Acces_to_resources: Jumlah baris: 6607 Tipe data: object Deskripsi: Akses fasilitas belajar siswa
# 5. Extracurricular_activities: Jumlah baris: 6607 Tipe data: object Deskripsi: Keikutsertaan Ekstrakurikuler siswa
# 6. Sleep_Hours: Jumlah baris: 6607 Tipe data: int64 Deskripsi: Jam tidur siswa
# 7. Previous_Scores: Jumlah baris: 6607 Tipe data: int64 Deskripsi: Nilai siswa sebelumnya
# 8. Motivation_Level: Jumlah baris: 6607 Tipe data: object Deskripsi: Tingkat motivasi belajar siswa
# 9. Internet_Access: Jumlah baris: 6607 Tipe data: object Deskripsi: Akses Internet Siswa
# 10. Tutoring_Sessions: Jumlah baris: 6607 Tipe data: int64 Deskripsi: Jumlah bimbingan belajar siswa
# 11. Family_Income: Jumlah baris 6607 Tipe data: object Deskripsi: Pendapatan keluarga siswa
# 12. Teacher_Quality: Jumlah baris: 6529 Tipe data: object Deskripsi: Kualitas guru siswa
# 13. Peer_Influence: Jumlah baris: 6607 Tipe data: object Deskripsi: Pengaruh teman sebaya siswa
# 14. Physical_Activity: Jumlah baris: 6607 Tipe data: int64 Deskripsi:Aktivitas fisik siswa
# 15. Learning_Disabilities: Jumlah baris: 6607 Tipe data: object  Deskripsi:Kesulitan belajar siswa
# 16. Parendal_Education_Level: Jumlah baris: 6517 Tipe data: object Deskripsi:Pendidikan orangtua siswa
# 17. Distance_from_home: Jumlah baris: 6540 Tipe data: object Deskripsi: Jarak rumah ke sekolah siswa
# 18. Gender: Jumlah baris: 6607 Tipe data: object Deskripsi: Jenis kelamim siswa
# 19. Exam_Score: Jumlah baris: 6607 Tipe data: int64 Deskripsi: Nilai ujian siswa

# %% [markdown]
# ### **Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#         Hours_Studied   Attendance Parental_Involvement Access_to_Resources  \
# count     6607.000000  6607.000000                 6607                6607
# unique            NaN          NaN                    3                   3
# top               NaN          NaN               Medium              Medium
# freq              NaN          NaN                 3362                3319
# mean        19.975329    79.977448                  NaN                 NaN
# std          5.990594    11.547475                  NaN                 NaN
# min          1.000000    60.000000                  NaN                 NaN
# 25%         16.000000    70.000000                  NaN                 NaN
# 50%         20.000000    80.000000                  NaN                 NaN
# 75%         24.000000    90.000000                  NaN                 NaN
# max         44.000000   100.000000                  NaN                 NaN
#
# ...

# %% [markdown]
# 1. Count (Kelengkapan data) Berdasarkan data, total baris adalah 6607. Maka dapat disimpulkan :
#
# * Teacher quality kehilangan 78 data (6607 - 6529)
# * Parental education level kehilangan 90 data (6607 - 6517)
# * Distance from home kehilangan 67 data (6607 - 6540)
# Kesimpulan : Kolom Teacher_quality, Parental_education_level, dan Distance_from_home mengandung missing values, sementara kolom lainnya lengkap yaitu 6607 data.
#
# ---
#
# 2. Mean vs Median (Distribusi Data)
# * Kolom Hours_Studied:
#   * Mean: 19,97
#   * Median: 20
#
#   Nilai rata-rata jam belajar lebih kecil, hampir setara dengan median.
#
#   Menunjukkan distribusi jam belajar cukup seimbang dan stabil.
# * Kolom Attendance:
#   * Mean: 79,9
#   * Median: 80
#
#   Nilai rata-rata kehadiran lebih kecil, hampir setara dengan median.
#
#   Menunjukkan distribusi kehadiran seimbang dan stabil.
#
# * Kolom Sleep_Hours:
#   * Mean: 7,02
#   * Median: 7
#
#   Nilai rata-rata jam tidur siswa sedikit lebih tinggi dari median
#
#   Menunjukkan beberapa siswa dengan jam tidur lebih tinggi.Namun secara umum jam tidur siswa mayoritas di angka 7 jam
#
# * Kolom Previous_Scores:
#   * Mean: 75,07
#   * Median: 75
#
#   Nilai rata-rata nilai siswa sebelumnya sedikit lebih tinggi dari median.
#
#   Menunjukkan terdapat beberapa siswa dengan nilai sebelumnya cukup tinggi. Namun secara umum nilai siswa sebelumnya sekitar di angka 75.
#
# * Kolom Tuttoring_Sessions:
#   * Mean: 1,4
#   * Median: 1,2
#
#   Nilai rata-rata jumlah bimbingan belajar siswa lebih tinggi dari median
#
#   Menunjukkan sebagian besar siswa mengikuti 1 sesi bimbingan belajar, namun ada beberapa siswa yang mengikuti lebih banyak sesi bimbingan belajar.
#
# * Kolom Physical_Activity:
#   * Mean: 2,9
#   * Median: 3
#
#   Nilai rata-rata aktivitas fisik siswa lebih kecil sedikit, hampir setara dengan median.
#
#   Menunjukkan sebagian besar siswa berada di tingkat aktivitas fisik tinggi. Namun ada beberaoa siswa dengan aktivitas fisik rendah.
#
# * Kolom Exam_Score:
#   * Mean: 67,2
#   * Median: 67
#   Nilai rata-rata sedikit lebih tinggi, hampir setara dengan median.
#
#   Menunjukkan nilai ujian siswa cukup merata.
#
#   Kesimpulan: Secara keseluruhan, data menunjukkan pola yang cukup seimbang dan stabil. Mayoritas siswa memiliki karakteristik yang tidak jauh berbeda satu sama lain dalam hal jam belajar, kehadiran, jam tidur, serta nilai akademik.
#
#   ---
#
# 3. Min dan Max (Validasi Logika)
# * Kolom Hours_Studied:
#   * Min: 1
#   * Max: 44
# * Kolom Attendance:
#   * Min: 60
#   * Max: 100
# * Kolom Sleep_Hours:
#   * Min: 4
#   * Max: 10
# * Kolom Previous_Scores:
#   * Min: 50
#   * Max: 100
# * Kolom Tuttoring_Sessions:
#   * Min: 0
#   * Max: 8
# * Kolom Physical_Activity:
#   * Min: 0
#   * Max: 6
# * Kolom Exam_Score:
#   * Min: 55
#   * Max: 101
#
# Kesimpulan:
# * Pada kolom Hours_Studied, rentang nilai dari 1 hingga 44 menunjukkan variasi jam belajar yang cukup besar antar siswa. Adanya nilai maksimum 44 jam mengindikasikan kemungkinan terdapat siswa yang belajar jauh lebih lama dibanding mayoritas lainnya.
#
# * Pada kolom Attendance, rentang 60 hingga 100 menunjukkan tingkat kehadiran yang masih dalam batas logis.
#
# * Pada kolom Sleep_Hours, rentang 4 hingga 10 jam menunjukkan perbedaan pola tidur siswa, namun masih dalam batas normal untuk usia sekolah.
#
# * Pada kolom Previous_Scores, rentang 50 hingga 100 menunjukkan variasi kemampuan akademik sebelumnya yang cukup lebar, dari siswa dengan performa sedang hingga sangat tinggi.
#
# * Pada kolom Tutoring_Sessions, rentang 0 hingga 8 sesi menunjukkan bahwa sebagian siswa tidak mengikuti bimbingan tambahan, sementara sebagian lainnya cukup mau mengikuti bimbingan.
#
# * Pada kolom Physical_Activity, rentang 0 hingga 6 menunjukkan tingkat aktivitas fisik yang beragam, dari siswa yang tidak aktif hingga sangat aktif.
#
# * Pada kolom Exam_Score, rentang 55 hingga 101 menunjukkan variasi hasil ujian yang cukup luas. Nilai maksimum 101 perlu divalidasi karena melebihi batas umum 100 dan kemungkinan merupakan bonus atau kesalahan input.
#
#
# ---
#
# 4. Standar Deviasi (std) - Variabilitas Data
#
# * Kolom Hours_Studied:
#   * Mean: 19,9
#   * Std: 5.9
# * Kolom Attendance:
#   * Mean: 79,9
#   * Std: 11,5
# * Kolom Sleep_Hours:
#   * Mean: 7,02
#   * Std: 1,4
# * Kolom Previous_Scores:
#   * Mean: 75,07
#   * Std: 14,3
# * Kolom Tutoring_Sessions:
#   * Mean: 1,4
#   * Std: 1,2
# * Kolom Physical_Activity:
#   * Mean: 2,9
#   * Std: 1,03
# * Kolom Exam_Score:
#   * Mean: 67,2
#   * Std: 3,8
#
# Kesimpulan:
# * Pada kolom Hours_Studied, nilai standar deviasi (5,9) sekitar 30% dari mean (19,9) menunjukkan variasi jam belajar siswa cukup beragam, namun masih dalam batas yang stabil.
#
# * Pada kolom Attendance, standar deviasi (11,5) sekitar 14% dari mean (79,9) menunjukkan tingkat kehadiran relatif konsisten dengan variasi sedang.
#
# * Pada kolom Sleep_Hours, standar deviasi (1,4) yang kecil dibandingkan mean (7,02) menunjukkan pola tidur siswa cukup stabil dan tidak terlalu bervariasi.
#
# * Pada kolom Previous_Scores, standar deviasi (14,3) sekitar 19% dari mean (75,07) menunjukkan adanya variasi kemampuan akademik sebelumnya yang cukup signifikan antar siswa.
#
# * Pada kolom Tutoring_Sessions, standar deviasi (1,2) yang mendekati mean (1,4) mengindikasikan jumlah sesi bimbingan cukup bervariasi antar siswa.
#
# * Pada kolom Physical_Activity, standar deviasi (1,03) sekitar 35% dari mean (2,9) menunjukkan variasi tingkat aktivitas fisik yang cukup terlihat.
#
# * Pada kolom Exam_Score, standar deviasi (3,8) yang relatif kecil dibandingkan mean (67,2) menunjukkan nilai ujian siswa cukup sama dan tidak terlalu menyebar jauh.

# %% [markdown]
# ## **Verifikasi Kualitas Data**

# %% [markdown]
# ### **Data Type Check**

# %%
df.dtypes
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %% [markdown]
# Kita akan mengecek tipe data dari setiap kolom apakah sudah sesuai atau tidak. Agar insight serta visualisasi yang akan kita buat menjadi akurat.
#
# Dapat dilihat diatas, semua kolom sudah sesuai dengan tipe data nya.

# %% [markdown]
# ### **Incosistent Values**

# %% [markdown]
# Pada tahap ini, kita perlu mengecek kekonsistenan data, contoh nya dalam penulisan. Hal ini dilakukan agar data tidak terduplikat dengan baris yang sebenarnya sama akan tetapi bisa terduplikat karena tidak konsisten.

# %% [markdown]
# **1. Parental Invlovement**
#
# Kolom Parental_Involvement sudah bersih dari inkonsistensi data dan siap digunakan untuk analisis.

# %%
print(df['Parental_Involvement'].unique())
# Out:
# ['Low' 'Medium' 'High']

# %% [markdown]
# **2. Access_to_Resources**
#
# Kolom Parental_Involvement sudah bersih dari inkonsistensi data dan siap digunakan untuk analisis.

# %%
print(df['Access_to_Resources'].unique())
# Out:
# ['High' 'Medium' 'Low']

# %% [markdown]
# **3. Extracurricular_Activities**
#
# Kolom Extracurricular_Activities sudah konsisten dan bersih dari inkonsistensi data, sehingga siap digunakan untuk analisis.

# %%
print(df['Extracurricular_Activities'].unique())
# Out:
# ['No' 'Yes']

# %% [markdown]
# **4. Motivation_Level**
#
# Kolom Motivation_Level sudah konsisten dan bersih dari inkonsistensi data, sehingga siap digunakan untuk analisis.

# %%
print(df['Motivation_Level'].unique())
# Out:
# ['Low' 'Medium' 'High']

# %% [markdown]
# **5. Internet_Access**
#
# Kolom Internet_Access sudah konsisten dan bersih dari inkonsistensi data, sehingga siap digunakan untuk analisis.

# %%
print(df['Internet_Access'].unique())
# Out:
# ['Yes' 'No']

# %% [markdown]
# **6. Family_Income**
#
# Kolom Internet_Access sudah konsisten dan bersih dari inkonsistensi data, sehingga siap digunakan untuk analisis.

# %%
print(df['Family_Income'].unique())
# Out:
# ['Low' 'Medium' 'High']

# %% [markdown]
# **7. Teacher_Quality**
#
# Kolom Teacher_Quality tidak memiliki inkonsistensi penulisan kategori, tetapi mengandung data kosong (missing values) yang perlu ditangani (imputasi atau penghapusan) sebelum analisis lebih lanjut.

# %%
print(df['Teacher_Quality'].unique())
# Out:
# ['Medium' 'High' 'Low' nan]

# %% [markdown]
# **8. School_Type**
#
# Kolom School_Type sudah konsisten dan bersih dari inkonsistensi data, sehingga siap digunakan untuk analisis.

# %%
print(df['School_Type'].unique())
# Out:
# ['Public' 'Private']

# %% [markdown]
# **9. Peer Influence**
#
# Kolom Peer_Influence sudah konsisten dan bersih dari inkonsistensi data, sehingga siap digunakan untuk analisis.

# %%
print(df['Peer_Influence'].unique())
# Out:
# ['Positive' 'Negative' 'Neutral']

# %% [markdown]
# **10. Learning_Disabilities**
#
# Kolom Learning_Disabilities sudah konsisten dan bersih dari inkonsistensi data, sehingga siap digunakan untuk analisis.

# %%
print(df['Learning_Disabilities'].unique())
# Out:
# ['No' 'Yes']

# %% [markdown]
# **11. Parental_Education_Level**
#
# Kolom Parental_Education_Level tidak memiliki inkonsistensi kategori, namun mengandung data kosong (missing values) yang perlu ditangani sebelum analisis lanjutan.

# %%
print(df['Parental_Education_Level'].unique())
# Out:
# ['High School' 'College' 'Postgraduate' nan]

# %% [markdown]
# **12. Distance_From_Home**
#
# Kolom Distance_from_Home tidak memiliki inkonsistensi kategori, namun mengandung data kosong (missing values) yang perlu ditangani sebelum analisis lanjutan.

# %%
print(df['Distance_from_Home'].unique())
# Out:
# ['Near' 'Moderate' 'Far' nan]

# %% [markdown]
# **13. Gender**
#
# Kolom Gender sudah konsisten dan bersih dari inkonsistensi data, sehingga siap digunakan untuk analisis.

# %%
print(df['Gender'].unique())
# Out:
# ['Male' 'Female']

# %% [markdown]
# ### **Missing Values**

# %% [markdown]
# Pada tahap ini kita akan melihat seberapa banyak data yang hilang pada seluruh kolom.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                             Null Ratio in %
# Hours_Studied                      0.000000
# Attendance                         0.000000
# Parental_Involvement               0.000000
# Access_to_Resources                0.000000
# Extracurricular_Activities         0.000000
# Sleep_Hours                        0.000000
# Previous_Scores                    0.000000
# Motivation_Level                   0.000000
# Internet_Access                    0.000000
# Tutoring_Sessions                  0.000000
# Family_Income                      0.000000
# Teacher_Quality                    1.180566
# School_Type                        0.000000
# Peer_Influence                     0.000000
# Physical_Activity                  0.000000
# Learning_Disabilities              0.000000
# Parental_Education_Level           1.362192
# Distance_from_Home                 1.014076
# Gender                             0.000000
# Exam_Score                         0.000000

# %% [markdown]
# * Teacher_Quality
#
# Memiliki missing values sekitar 1,18%, yang dimana jumlah ini tergolong kecil. Namun tetap perlu ditangani (imputasi atau penghapusan) agar tidak memengaruhi hasil analisis.
#
# * Parental_Education_Level
#
# Memiliki missing values sekitar 1,36%, yang dimana persentasenya rendah. Missing values ini dapat ditangani dengan imputasi kategori yang paling sering muncul (mode) atau metode lain yang sesuai.
#
# * Distance_from_Home
#
# Memiliki missing values sekitar 1,01%, yang dimana jumlahnya juga relatif kecil. Data ini tetap perlu ditangani sebelum proses analisis atau modeling.

# %% [markdown]
# ### **Duplicated Values**

# %% [markdown]
# Pada tahap ini, kita akan mengecek duplikasi pada dataset. Hal ini dilakukan agar dataset memiliki insight dan hasil yang bersih.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Hours_Studied, Attendance, Parental_Involvement, Access_to_Resources, Extracurricular_Activities, Sleep_Hours, Previous_Scores, Motivation_Level, Internet_Access, Tutoring_Sessions, Family_Income, Teacher_Quality, School_Type, Peer_Influence, Physical_Activity, Learning_Disabilities, Parental_Education_Level, Distance_from_Home, Gender, Exam_Score]
# Index: []

# %% [markdown]
# Terlihat pada dataset ini tidak ada duplikasi. Maka hal ini tidak perlu ditangani.

# %% [markdown]
# ### **Outliers Values**

# %% [markdown]
# Pada tahap ini, kita akan melihat nilai ekstrem (outliers) pada kolom yang bertipe data kan numerik. Hal ini dilakukan agar mendapatkan insight yang akurat sehingga dapat memperkuat analisis dan model yang akan kita bangun nantinya.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom              Persentase Outliers
# Hours_Studied                 0.650825
# Attendance                    0.000000
# Sleep_Hours                   0.000000
# Previous_Scores               0.000000
# Tutoring_Sessions             6.508249
# Physical_Activity             0.000000
# Exam_Score                    1.574088

# %% [markdown]
# * Hours_Studied
#
# Dengan persentase 0,65%
#
# * Tutoring_Sessions
#
# Dengan persentase 6,5%
#
# * Exam_Score
#
# Dengan persentase 1.57%

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Hours_Studied'])
plt.title('Boxplot of Hours_Studied')
plt.ylabel('Hours_Studied')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Tutoring_Sessions'])
plt.title('Boxplot of tutoring_Sessions')
plt.ylabel('Tutoring_Sessions')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Exam_Score'])
plt.title('Boxplot of Exam_Score')
plt.ylabel('Exam_Score')
plt.show()

# %% [markdown]
# # **Eksplorasi Data**

# %% [markdown]
# ## **Comparison / Perbandingan**

# %% [markdown]
# Aktivitas: Membandingkan antara jam belajar siswa dengan nilai ujian siswa
#
# Tujuan: Mengetahui apakah jumlah jam belajar berpengaruh terhadap nilai ujian.
#
# Visualisasi: Histogram

# %%
penjualan_market = df.groupby('Hours_Studied')['Exam_Score'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=penjualan_market.index, y=penjualan_market.values, palette='viridis', hue=penjualan_market.index, legend=False)
plt.title('Total Jam Belajar Siswa Berdasarkan Nilai Ujian Siswa')
plt.xlabel('Nilai Ujian Siswa')
plt.ylabel('Jam Belajar Siswa')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Kesimpulan:
#
# Secara keseluruhan, visualisasi menunjukkan bahwa jam belajar berkontribusi terhadap peningkatan nilai ujian, meskipun tidak sepenuhnya linear dan terdapat variasi pada nilai yang sangat tinggi.

# %% [markdown]
# ## **Composition / Komposisi**

# %% [markdown]
# Aktivitas: Melihat proporsi atau persentase nilai ujian siswa berdasarkan jam tidur siswa.
#
# Tujuan: Mengetahui kategori jam tidur siswa yang paling mendominasi nilai ujian siswa secara keseluruhan.
#
# Visualisasi: Pie Chart

# %%
sales_by_category = df.groupby('Teacher_Quality')['Exam_Score'].sum().sort_values(ascending=False)
sales_by_category_top3 = sales_by_category.head(3)

plt.figure(figsize=(10, 8))
sales_by_category_top3.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Proporsi 3 kategori gender siswa Berdasarkan Nilai Ujian Siswa')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# Kesimpulan:
#
# Mayoritas siswa memiliki nilai ujian pada tingkat sedang, cukup banyak yang memiliki nilai tinggi, dan hanya sedikit yang memperoleh nilai rendah. Secara umum, performa siswa cenderung berada pada kategori menengah ke atas.

# %% [markdown]
# ## **Distribution / Distribusi**

# %% [markdown]
# Aktivitas: Menganalisis penyebaran nilai pada kolom nilai ujian siswa(Exam_Score).
#
# Tujuan: Melihat apakah mayoritas bernilai kecil atau besar, serta mendeteksi adanya kecondongan dalam data nilai ujian siswa.
#
# Visualisasi: Histogram.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Exam_Score'], bins=20, kde=True)
plt.title('Distribusi Nilai Ujian Siswa')
plt.xlabel('Exam_Score')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Kesimpulan:
#
# Secara umum, performa siswa tergolong stabil dan terkonsentrasi di nilai menengah ke atas, dengan rata-rata sekitar akhir 60-an.

# %% [markdown]
# ## **Relationship / Hubungan**

# %% [markdown]
# Aktivitas: Menganalisis korelasi antara jam tidur siswa (Hours_Studied) dengan nilai ujian siswa (Exam_Score).
#
# Tujuan: Mengetahui apakah peningkatan jam tidur siswa selalu berbanding lurus dengan peningkatan nilai ujian siswa.
#
# Visualisasi: Heatmap

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['Hours_Studied', 'Exam_Score']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi antara Jam tidur siswa dan Nilai ujian siswa')
plt.show()

# %% [markdown]
# Kesimpulan:
#
# Semakin banyak jam belajar, cenderung semakin tinggi nilai ujian, tetapi hubungannya tidak terlalu kuat.

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Tipe Data**

# %% [markdown]
# Pada tahap ini kita akan memperbaiki atau mengubah kolom yang tipe data nya tidak sesuai dengan yang cocok.

# %%
df.dtypes
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %% [markdown]
# Bisa dilihat diatas, semua kolom sesuai dengan tipe data yang cocok, jadi tidak perlu ditangani.

# %% [markdown]
# ## **Missing Values**

# %% [markdown]
# Pada tahap ini, kita akan menangani atau membersihkan data yang kosong atau tidak terisi pada suatu kolom.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                             Null Ratio in %
# Hours_Studied                      0.000000
# Attendance                         0.000000
# Parental_Involvement               0.000000
# Access_to_Resources                0.000000
# Extracurricular_Activities         0.000000
# Sleep_Hours                        0.000000
# Previous_Scores                    0.000000
# Motivation_Level                   0.000000
# Internet_Access                    0.000000
# Tutoring_Sessions                  0.000000
# Family_Income                      0.000000
# Teacher_Quality                    1.180566
# School_Type                        0.000000
# Peer_Influence                     0.000000
# Physical_Activity                  0.000000
# Learning_Disabilities              0.000000
# Parental_Education_Level           1.362192
# Distance_from_Home                 1.014076
# Gender                             0.000000
# Exam_Score                         0.000000

# %% [markdown]
# Bisa dilihat diatas, ada kolom yang memiliki missing values.
#
#
# * Kolom Teacher_Quality dengan persentase 1.18%
# * Kolom Parental_Education_Level dengan persentase 1.36%
# * Kolom Distance_Form_Home dengan persentase 1.01%
#
# Maka ini perlu ditangani. Karena kolom yang mempunyai missing values adalah tipe data object maka kita menangani dengan menggunakan modus.

# %%
df['Teacher_Quality'] = df['Teacher_Quality'].fillna(df['Teacher_Quality'].dropna().mode()[0])
df['Parental_Education_Level'] = df['Parental_Education_Level'].fillna(df['Parental_Education_Level'].dropna().mode()[0])
df['Distance_from_Home'] = df['Distance_from_Home'].fillna(df['Distance_from_Home'].dropna().mode()[0])

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                             Null Ratio in %
# Hours_Studied                           0.0
# Attendance                              0.0
# Parental_Involvement                    0.0
# Access_to_Resources                     0.0
# Extracurricular_Activities              0.0
# Sleep_Hours                             0.0
# Previous_Scores                         0.0
# Motivation_Level                        0.0
# Internet_Access                         0.0
# Tutoring_Sessions                       0.0
# Family_Income                           0.0
# Teacher_Quality                         0.0
# School_Type                             0.0
# Peer_Influence                          0.0
# Physical_Activity                       0.0
# Learning_Disabilities                   0.0
# Parental_Education_Level                0.0
# Distance_from_Home                      0.0
# Gender                                  0.0
# Exam_Score                              0.0

# %% [markdown]
# Bisa dilihat diatas, setelah melakukan penanganan missing values yang terdapat pada kolom Teacher_Quality, Parental_Education_Level, dan Distance_from_Home, Kolom tersebut sudah tidak memiliki missing values.

# %% [markdown]
# ## **Inconsistent Values**

# %% [markdown]
# Pada tahap ini kita akan menangani atau mengubah data yang tidak konsisten dalam format atau penulisan.

# %%
print(df['Hours_Studied'].unique())
print(df['Attendance'].unique())
print(df['Access_to_Resources'].unique())
print(df['Extracurricular_Activities'].unique())
print(df['Sleep_Hours'].unique())
print(df['Previous_Scores'].unique())
print(df['Motivation_Level'].unique())
print(df['Internet_Access'].unique())
print(df['Tutoring_Sessions'].unique())
print(df['Family_Income'].unique())
print(df['Teacher_Quality'].unique())
print(df['School_Type'].unique())
print(df['Peer_Influence'].unique())
print(df['Physical_Activity'].unique())
print(df['Learning_Disabilities'].unique())
print(df['Parental_Education_Level'].unique())
print(df['Distance_from_Home'].unique())
print(df['Gender'].unique())
print(df['Exam_Score'].unique())
# Out:
# [23 19 24 29 25 17 21  9 10 14 22 15 12 20 11 13 16 18 31  8 26 28  4 35
#  27 33 36 43 34  1 30  7 32  6 38  5  3  2 39 37 44]
# [ 84  64  98  89  92  88  78  94  80  97  83  82  68  60  70  75  99  74
#   65  62  91  90  66  69  72  63  61  86  77  71  67  87  73  96 100  81
#   95  79  85  76  93]
# ['High' 'Medium' 'Low']
# ['No' 'Yes']
# [ 7  8  6 10  9  5  4]
# [ 73  59  91  98  65  89  68  50  80  71  88  87  97  72  74  70  82  58
#   99  84 100  75  54  90  94  51  57  66  96  93  56  52  63  79  81  69
#   95  60  92  77  62  85  78  64  76  55  86  61  53  83  67]
# ['Low' 'Medium' 'High']
# ['Yes' 'No']
# [0 2 1 3 4 5 6 7 8]
# ['Low' 'Medium' 'High']
# ['Medium' 'High' 'Low' nan]
# ['Public' 'Private']
# ['Positive' 'Negative' 'Neutral']
# [3 4 2 1 5 0 6]
# ['No' 'Yes']
# ['High School' 'College' 'Postgraduate' nan]
# ['Near' 'Moderate' 'Far' nan]
# ['Male' 'Female']
# [ 67  61  74  71  70  66  69  72  68  65  64  60  63  62 100  76  79  73
# ...

# %% [markdown]
# Bisa dilihat diatas nilai nilai pada kolom tidak memiliki inconsistent values, sehingga tidak perlu ditagani dan bisa dilanjut untuk analisis.

# %% [markdown]
# ## **Duplicated Values**

# %% [markdown]
# Pada tahap ini kita akan menangani atau membersihkan data yang tercatat lebih dari satu kali (data ganda).

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Hours_Studied, Attendance, Parental_Involvement, Access_to_Resources, Extracurricular_Activities, Sleep_Hours, Previous_Scores, Motivation_Level, Internet_Access, Tutoring_Sessions, Family_Income, Teacher_Quality, School_Type, Peer_Influence, Physical_Activity, Learning_Disabilities, Parental_Education_Level, Distance_from_Home, Gender, Exam_Score]
# Index: []

# %% [markdown]
# Bisa dilihat diatas, kolom dan baris tidak memiliki duplicated values, sehingga ini tidak perlu ditangani dan bisa dilanjut untuk analisis.

# %% [markdown]
# ## **Outliers**

# %% [markdown]
# Pada tahap ini kita akan menangani atau membersihkan nilai yang sangat jauh berbeda dari mayoritas data (nilai ekstrem).

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom              Persentase Outliers
# Hours_Studied                 0.650825
# Attendance                    0.000000
# Sleep_Hours                   0.000000
# Previous_Scores               0.000000
# Tutoring_Sessions             6.508249
# Physical_Activity             0.000000
# Exam_Score                    1.574088

# %% [markdown]
# Berdasarkan kolom diatas, ada beberapa kolom yang memiliki nilai outlier. Yaitu:
#
# * Kolom Hours_Studied dengan persentase 0.65%
# * Kolom Tutoring_Sessions dengan persentase 6.50%
# * Kolom Exam_Score dengan persentase 1.57%
#
# Maka ini perlu ditangani.

# %%
columns_to_impute = ["Hours_Studied", "Tutoring_Sessions", "Exam_Score"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)
# Out:
# /tmp/ipykernel_550/1334474803.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 2. 2. ... 3. 2. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom              Persentase Outliers
# Hours_Studied                      0.0
# Attendance                         0.0
# Sleep_Hours                        0.0
# Previous_Scores                    0.0
# Tutoring_Sessions                  0.0
# Physical_Activity                  0.0
# Exam_Score                         0.0

# %% [markdown]
# Bisa dilihat diatas, setelah penanganan nilai outlier pada kolom Hours_Studied, Tutoring_Sessions, dan Exam_Score, kolom tersebut sudah tidak memiliki nilai outlier.

# %% [markdown]
# ## **Data Construction**

# %% [markdown]
# Data Construction adalah proses membuat atau menambahkan variabel (fitur) baru dari data yang sudah ada untuk memperkaya informasi dan mempermudah analisis.

# %%
def categorize_Exam_Score(Exam_Score):
    if Exam_Score > 64:
        return 'A'
    elif Exam_Score < 65:
        return 'B'
    else:
        return 'Break Even'

df['Category_Exam_Score'] = df['Exam_Score'].apply(categorize_Exam_Score)

# %% [markdown]
# Disini saya menambahkan kolom baru yaitu Category_Exam_Score untuk mendefinisikan nilai ujian siswa (Exam_Score) apakah nilai tersebut termasuk A atau B.

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# Bisa dilihat diatas, kolom Category_Exam_Score sudah tertambah dan nilai pada kolom berdasarkan pada nilai dari kolom Exam_Score.

# %% [markdown]
# ## **Data Reduction**

# %% [markdown]
# Data Reduction adalah proses menyederhanakan atau mengurangi jumlah data tanpa menghilangkan informasi penting, agar data lebih efisien untuk dianalisis.

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# Berdasarkan pada dataset tersebut, tidak ada kolom yang perlu dihapus.Karena masing-masing masih memiliki peran dan relevansi terhadap analisis performa siswa.

# %% [markdown]
# # **Menyimpan Dataset Bersih**

# %%
df.to_excel('(Bersih)StudentPerformanceFactors.xlsx', index= False)

# %% [markdown]
# # **Visualisasi Data**

# %% [markdown]
# ## **Bar Chart**

# %%
top_parentaleducation = df['Parental_Education_Level'].value_counts().head(5).sort_values(ascending=False)

plt.figure(figsize=(10, 6))
plt.bar(top_parentaleducation.index, top_parentaleducation.values, color='skyblue')
plt.xlabel('Pendidikan Orangtua Siswa')
plt.ylabel('Jumlah')
plt.title('PENDIDIKAN ORANGTUA SISWA TERBANYAK')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Insight : Mayoritas orang tua siswa di sini ternyata lulusan SMA, jumlahnya paling dominan sampai tembus 3.000 orang lebih. Makin tinggi jenjang pendidikannya, jumlahnya justru makin merosot.Lulusan College ada di angka 2.000 an, sedangkan lulusan Pascasarjana jadi yang paling sedikit di angka 1.300 an.
#
# Action : Sekolah perlu menggunakam bahasa yang simpel dan membumi supaya info penting bisa beneran sampai ke orang tua tanpa bikin bingung.

# %% [markdown]
# ## **Pie Chart**

# %%
plt.figure(figsize=(10, 6))
plt.pie(df['Parental_Involvement'].value_counts(), labels=df['Parental_Involvement'].value_counts().index, autopct='%1.1f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold']) # colors (warna)
plt.title('Distribusi Keterlibatan Orangtua Siswa')
plt.show()

# %% [markdown]
# Insight : Kebanyakan orang tua siswa di sini adalah lulusan SMA, jumlahnya paling dominan di angka 3.300 orang lebih. Di bawahnya, ada lulusan College yang berjumlah sekitar 2.000 orang, sementara lulusan Pascasarjana jadi kelompok paling kecil dengan jumlh cuma 1.300 an orang.
#
# Action : Sekolah harus bisa memanfaatkan situasi ini dengan bikin panduan belajar yang teknis tapi gampang dipahami.

# %% [markdown]
# ## **Linechart**

# %% [markdown]
# Disini saya tidak menggunakan visualisasi Linechart karena pada dataset ini tidak terdapat kolom waktu dan juga tidak sesuai untuk melihat tren waktu pada dataset ini.

# %% [markdown]
# ## **Histogram**

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Exam_Score'], bins=20, color='pink', edgecolor='black')
plt.title('Distribusi Nilai Ujian Siswa')
plt.xlabel('Nilai Ujian Siswa')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Insight : Mayoritas siswa terkonsentrasi pada rentang nilai menengah antara 64 hingga 70, dengan puncak frekuensi tertinggi berada di angka 68.
#
# Action : perlu melakukan audit data dulu buat memastikan apakah celah nilai tadi memang murni hasil ujian siswa atau cuma kesalahan teknis pas penarikan laporan.

# %% [markdown]
# ## **Box Plot**

# %%
top3pendidikanorangtua = df['Parental_Education_Level'].value_counts().head(5).index
df_top3_parentallevel = df[df['Parental_Education_Level'].isin(top3pendidikanorangtua)]

plt.figure(figsize=(12, 7))
df_top3_parentallevel.boxplot(column='Exam_Score', by='Parental_Education_Level', ax=plt.gca(), grid=False, patch_artist=True, medianprops=dict(color='red'))
plt.title('Distribusi Nilai Ujian Siswa Berdasarkan Pendidikan Orangtua Siswa', fontsize=16)
plt.xlabel('Pendidkan Orangtua Siswa', fontsize=12)
plt.ylabel('Nilai Ujian Siswa', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.suptitle('')
plt.tight_layout()
plt.show()

# %% [markdown]
# Insight : Meskipun rata-rata nilai ujian siswa kebanyakan ngumpul di angka 64–70, data box plot menunjukkan kalau anak-anak dari orang tua lulusan Pascasarjana punya performa yang lebih stabil. Median nilai mereka lebih tinggi (sekitar 68) dan rentang nilai bawahnya lebih terjaga dibanding kelompok lain.
#
# Action : Sekolah perlu banget kasih perhatian ekstra dan pendampingan tambahan buat siswa yang orang tuanya lulusan SMA.

# %% [markdown]
# ## **Scatter Plot**

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Exam_Score'], df['Hours_Studied'], alpha=0.7, color='teal')
plt.title('Hubungan antara Nilai Ujian Siswa dan Nilai Siswa Sebelumnya ', fontsize=16)
plt.xlabel('Nilai Ujian Siswa', fontsize=12)
plt.ylabel('Nilai Siswa Sebelumnya', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Insight : korelasi positif yang kuat antara nilai ujian siswa yang sekarang sama nilai mereka yang dulu.
#
# Action : Sekolah disarankan buat pasang sistem peringatan terutama buat siswa yang punya riwayat nilai di bawah 15.

# %% [markdown]
# ## **Heat Map**

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['Exam_Score', 'Previous_Scores']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi antara Nilai Ujian Siswa dan Nilai Siswa Sebelumnya')
plt.show()

# %% [markdown]
# Insight : Meskipun terdapat korelasi positif antara nilai ujian saat ini dengan nilai sebelumnya, kekuatan korelasi tersebut tergolong lemah dengan koefisien sebesar 0.20.
#
# Action : Karena pengaruh nilai sebelumnya terhadap nilai ujian cukup kecil, perlu mempertimbangkan faktor lain yang mungkin lebih memengaruhi hasil ujian, seperti kualitas pengajaran, waktu belajar, tingkat kehadiran, atau metode belajar siswa.
